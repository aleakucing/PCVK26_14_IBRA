# %% [markdown]
# <a href="https://colab.research.google.com/github/aleakucing/PCVK26_14_IBRA/blob/main/P2_PraktikumD1_14_Ibra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK_2026/ktm.jpeg')
cv2_imshow(img)
print("Resolusi gambar: ", img.shape[1], " x ", img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=1289x833>
# Resolusi gambar:  1289  x  833

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_2026/ktm.jpeg')
plt.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_2026/ktm.jpeg')
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_2026/ktm.jpeg')
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()

# %%
img_grey = cv.imread('/content/drive/MyDrive/PCVK_2026/ktm.jpeg', cv.IMREAD_GRAYSCALE)

#tanpa cmap
plt.subplot(1,2,1)
plt.imshow(img_grey)
plt.title('tanpa cmap')

#dengan cmap
plt.subplot(1,2,2)
plt.imshow(img_grey, cmap='gray')
plt.title('dengan cmap')

plt.show()

# %%
plt.imshow(img_grey, cmap='magma')
plt.show()

# %%
#resizeing
imgRBG = cv.cvtColor(img, cv.COLOR_BGR2RGB)
imgOUTPUT = cv.resize(imgRBG, (347,229))
plt.imshow(imgOUTPUT)

# %%
#flipping
imgFlip = cv.flip(imgRBG, 1)
plt.imshow(imgFlip)

# %%
#memperbesar ukuran canvas yang lebih besar dengan posisi gambar terbalik
imgFlip = cv.flip(imgRBG, 1)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)
ax.imshow(imgFlip)

# %%
#6. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

black_img = np.zeros((500,500,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(290,0), pt2=(520,130), color=(0,0,255), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(250,250), pt2=(350,350), color=(255,0,0), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(150,150), radius=60, color=(0,255,0), thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(0,255,0), thickness=-1)
cv.line(black_img, pt1=(0,0), pt2=(530,530), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='PCVK is fun!', org=(10,500), fontFace=font, fontScale=2, color=(255,255,0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros((500,500,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[150,350],[250,250],[450,350],[250,450]], dtype=np.int32)
vertices
# Out:
# array([[150, 350],
#        [250, 250],
#        [450, 350],
#        [250, 450]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[150, 350]],
#
#        [[250, 250]],
#
#        [[450, 350]],
#
#        [[250, 450]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(0,255,0), thickness=5)
plt.imshow(black_img2)
